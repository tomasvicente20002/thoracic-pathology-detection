# %% [markdown]
# # 🔍 YOLOv8 - Deteção com Filtragem Manual por IOU (NMS)
# Este notebook executa deteção de objetos usando um modelo YOLOv8 treinado, aplicando Non-Maximum Suppression (NMS) manual para eliminar caixas sobrepostas com base no limiar de IOU.

# %%
# Instalação necessária (caso ainda não esteja instalada)
# !pip install ultralytics opencv-python
# Out:
# Requirement already satisfied: ultralytics in c:\users\lynxv\anaconda3\lib\site-packages (8.3.162)
# Requirement already satisfied: opencv-python in c:\users\lynxv\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (2.7.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (0.22.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\lynxv\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lynxv\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lynxv\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lynxv\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lynxv\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lynxv\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lynxv\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (75.1.0)
# Requirement already satisfied: colorama in c:\users\lynxv\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\lynxv\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lynxv\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lynxv\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)

# %%
from ultralytics import YOLO
import cv2
import os
import torch
import torchvision.ops as ops

# %% [markdown]
# ## ⚙️ Configurações do modelo e parâmetros

# %%
# Caminho relativo (a partir do local onde está o notebook)
MODELO = 'runs/content/runs/detect/yolov8m_chest_v2_focal_colab/weights/best.pt'

PASTA_IMAGENS = '../Project/data_set/images_002/images'

# Thresholds
THRESHOLD = 0.3
IOU_THRESHOLD = 0.4  # Threshold para Non-Maximum Suppression

# %% [markdown]
# ## 🧮 Fórmula da Interseção sobre União (IOU)
# **IOU** mede a sobreposição entre duas bounding boxes. A fórmula é:
#
# $$ IOU = \frac{Área\ da\ Interseção}{Área\ da\ União} $$
#
# Usa-se para decidir se duas caixas estão demasiado próximas e apenas a de maior confiança deve ser mantida.

# %%
# Carregar o modelo YOLO treinado
model = YOLO(MODELO)

# %%
def filtrar_por_iou(boxes, scores, labels, iou_thresh=0.4):
    if len(boxes) == 0:
        return [], [], []
    keep_idxs = ops.nms(torch.tensor(boxes, dtype=torch.float32),
                       torch.tensor(scores, dtype=torch.float32),
                       iou_thresh)
    boxes_filtradas = [boxes[i] for i in keep_idxs]
    scores_filtrados = [scores[i] for i in keep_idxs]
    labels_filtradas = [labels[i] for i in keep_idxs]
    return boxes_filtradas, scores_filtrados, labels_filtradas

# %%
for nome_ficheiro in os.listdir(PASTA_IMAGENS):
    if nome_ficheiro.lower().endswith(('.jpg', '.jpeg', '.png')):
        caminho_imagem = os.path.join(PASTA_IMAGENS, nome_ficheiro)
        results = model(caminho_imagem)
        img = cv2.imread(caminho_imagem)

        boxes, scores, labels = [], [], []

        for box in results[0].boxes:
            conf = float(box.conf[0])
            if conf >= THRESHOLD:
                cls = int(box.cls[0])
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                boxes.append([x1, y1, x2, y2])
                scores.append(conf)
                labels.append(model.names[cls])

        if boxes:
            print(f"⚠️ Deteções na imagem: {nome_ficheiro}")
            boxes_filtradas, scores_filtrados, labels_filtradas = filtrar_por_iou(
                boxes, scores, labels, iou_thresh=IOU_THRESHOLD)

            for box, conf, nome in zip(boxes_filtradas, scores_filtrados, labels_filtradas):
                x1, y1, x2, y2 = box
                label = f"{nome} {conf:.2f}"
                cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
                (text_width, text_height), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 1)
                cv2.rectangle(img, (x1, y1 - text_height - 6), (x1 + text_width, y1), (0, 255, 0), -1)
                cv2.putText(img, label, (x1, y1 - 4), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 1)
                print(f" → {nome}: {conf:.2f} - Caixa: {[x1, y1, x2, y2]}")

            cv2.imshow("Deteções", img)
            cv2.waitKey(0)
            cv2.destroyAllWindows()

print("✅ Processo concluído.")
# Out:
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001336_000.png: 640x640 (no detections), 512.1ms
# Speed: 8.2ms preprocess, 512.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001337_000.png: 640x640 (no detections), 440.0ms
# Speed: 7.9ms preprocess, 440.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001338_000.png: 640x640 (no detections), 446.2ms
# Speed: 7.0ms preprocess, 446.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001338_001.png: 640x640 2 Consolidations, 459.2ms
# Speed: 7.9ms preprocess, 459.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001338_001.png
#  → Consolidation: 0.69 - Caixa: [137, 257, 435, 868]
#  → Consolidation: 0.31 - Caixa: [571, 283, 861, 981]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001338_002.png: 640x640 (no detections), 483.5ms
# Speed: 6.5ms preprocess, 483.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001338_003.png: 640x640 (no detections), 460.8ms
# Speed: 7.7ms preprocess, 460.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001339_000.png: 640x640 (no detections), 435.6ms
# Speed: 7.5ms preprocess, 435.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001340_000.png: 640x640 (no detections), 424.5ms
# Speed: 7.1ms preprocess, 424.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001341_000.png: 640x640 (no detections), 457.6ms
# Speed: 8.0ms preprocess, 457.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001342_000.png: 640x640 2 Consolidations, 2 Fibrosiss, 451.0ms
# Speed: 7.9ms preprocess, 451.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001342_000.png
#  → Consolidation: 0.85 - Caixa: [575, 174, 813, 910]
#  → Fibrosis: 0.77 - Caixa: [150, 83, 470, 846]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001342_001.png: 640x640 2 Emphysemas, 2 Fibrosiss, 477.0ms
# Speed: 6.0ms preprocess, 477.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001342_001.png
#  → Fibrosis: 0.84 - Caixa: [110, 253, 418, 812]
#  → Fibrosis: 0.74 - Caixa: [581, 220, 844, 837]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001343_000.png: 640x640 (no detections), 494.5ms
# Speed: 7.2ms preprocess, 494.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001344_000.png: 640x640 (no detections), 470.2ms
# Speed: 7.2ms preprocess, 470.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001345_000.png: 640x640 (no detections), 436.2ms
# Speed: 5.4ms preprocess, 436.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001346_000.png: 640x640 (no detections), 433.0ms
# Speed: 7.1ms preprocess, 433.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001347_000.png: 640x640 (no detections), 444.3ms
# Speed: 7.1ms preprocess, 444.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001347_001.png: 640x640 (no detections), 454.0ms
# Speed: 5.3ms preprocess, 454.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001347_002.png: 640x640 (no detections), 453.7ms
# Speed: 7.6ms preprocess, 453.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001348_000.png: 640x640 (no detections), 449.2ms
# Speed: 7.2ms preprocess, 449.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001349_000.png: 640x640 (no detections), 446.3ms
# Speed: 7.0ms preprocess, 446.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001350_000.png: 640x640 (no detections), 427.7ms
# Speed: 7.1ms preprocess, 427.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001351_000.png: 640x640 (no detections), 453.5ms
# Speed: 6.4ms preprocess, 453.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001352_000.png: 640x640 (no detections), 449.8ms
# Speed: 6.1ms preprocess, 449.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001353_000.png: 640x640 (no detections), 453.1ms
# Speed: 7.2ms preprocess, 453.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001354_000.png: 640x640 (no detections), 455.6ms
# Speed: 5.9ms preprocess, 455.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_000.png: 640x640 (no detections), 453.5ms
# Speed: 6.2ms preprocess, 453.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_001.png: 640x640 (no detections), 453.9ms
# Speed: 7.2ms preprocess, 453.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_002.png: 640x640 1 Atelectasis, 451.8ms
# Speed: 7.1ms preprocess, 451.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001355_002.png
#  → Atelectasis: 0.87 - Caixa: [307, 489, 463, 683]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_003.png: 640x640 (no detections), 470.1ms
# Speed: 7.5ms preprocess, 470.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_004.png: 640x640 1 Effusion, 458.4ms
# Speed: 5.5ms preprocess, 458.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001355_004.png
#  → Effusion: 0.71 - Caixa: [198, 493, 498, 916]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_005.png: 640x640 1 Fibrosis, 452.4ms
# Speed: 7.9ms preprocess, 452.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_006.png: 640x640 1 Atelectasis, 1 Effusion, 1 Fibrosis, 452.1ms
# Speed: 10.1ms preprocess, 452.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001355_006.png
#  → Atelectasis: 0.82 - Caixa: [205, 492, 345, 551]
#  → Effusion: 0.41 - Caixa: [560, 408, 844, 680]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_007.png: 640x640 (no detections), 454.2ms
# Speed: 5.7ms preprocess, 454.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_008.png: 640x640 (no detections), 446.2ms
# Speed: 5.4ms preprocess, 446.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_009.png: 640x640 (no detections), 409.7ms
# Speed: 5.5ms preprocess, 409.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_010.png: 640x640 (no detections), 404.3ms
# Speed: 6.7ms preprocess, 404.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_011.png: 640x640 (no detections), 432.0ms
# Speed: 5.7ms preprocess, 432.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001355_012.png: 640x640 1 Fibrosis, 447.0ms
# Speed: 6.8ms preprocess, 447.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001355_012.png
#  → Fibrosis: 0.61 - Caixa: [609, 563, 698, 709]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001356_000.png: 640x640 (no detections), 473.9ms
# Speed: 5.9ms preprocess, 473.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001357_000.png: 640x640 1 Fibrosis, 2 Fractures, 437.0ms
# Speed: 5.2ms preprocess, 437.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001357_000.png
#  → Fibrosis: 0.54 - Caixa: [638, 159, 860, 444]
#  → Fracture: 0.44 - Caixa: [712, 294, 816, 378]
#  → Fracture: 0.43 - Caixa: [801, 257, 887, 343]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001358_000.png: 640x640 (no detections), 475.4ms
# Speed: 6.0ms preprocess, 475.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001358_001.png: 640x640 (no detections), 459.1ms
# Speed: 6.9ms preprocess, 459.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001359_000.png: 640x640 (no detections), 493.3ms
# Speed: 7.2ms preprocess, 493.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001360_000.png: 640x640 (no detections), 465.8ms
# Speed: 6.0ms preprocess, 465.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001361_000.png: 640x640 (no detections), 520.0ms
# Speed: 8.3ms preprocess, 520.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_000.png: 640x640 (no detections), 465.4ms
# Speed: 7.4ms preprocess, 465.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_001.png: 640x640 1 Consolidation, 2 Effusions, 456.7ms
# Speed: 5.3ms preprocess, 456.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001362_001.png
#  → Consolidation: 0.90 - Caixa: [98, 223, 379, 741]
#  → Effusion: 0.82 - Caixa: [486, 233, 779, 812]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_002.png: 640x640 1 Effusion, 469.3ms
# Speed: 6.1ms preprocess, 469.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001362_002.png
#  → Effusion: 0.85 - Caixa: [539, 493, 817, 746]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_003.png: 640x640 (no detections), 469.2ms
# Speed: 7.3ms preprocess, 469.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_004.png: 640x640 1 Effusion, 456.3ms
# Speed: 7.3ms preprocess, 456.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_005.png: 640x640 1 Effusion, 450.4ms
# Speed: 6.3ms preprocess, 450.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_006.png: 640x640 1 Effusion, 458.6ms
# Speed: 6.9ms preprocess, 458.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001362_006.png
#  → Effusion: 0.34 - Caixa: [586, 447, 845, 645]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_007.png: 640x640 2 Consolidations, 2 Effusions, 1 Nodule, 479.9ms
# Speed: 7.4ms preprocess, 479.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001362_007.png
#  → Nodule: 0.84 - Caixa: [653, 303, 689, 343]
#  → Effusion: 0.76 - Caixa: [557, 228, 841, 593]
#  → Consolidation: 0.43 - Caixa: [679, 397, 819, 516]
#  → Effusion: 0.32 - Caixa: [152, 455, 428, 829]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_008.png: 640x640 (no detections), 473.6ms
# Speed: 5.5ms preprocess, 473.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_009.png: 640x640 (no detections), 433.6ms
# Speed: 5.5ms preprocess, 433.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_010.png: 640x640 1 Fibrosis, 410.6ms
# Speed: 6.9ms preprocess, 410.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001362_010.png
#  → Fibrosis: 0.47 - Caixa: [744, 347, 846, 387]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_011.png: 640x640 1 Consolidation, 2 Effusions, 462.1ms
# Speed: 6.1ms preprocess, 462.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001362_011.png
#  → Effusion: 0.83 - Caixa: [653, 458, 955, 719]
#  → Effusion: 0.34 - Caixa: [599, 466, 993, 1024]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_012.png: 640x640 2 Atelectasiss, 1 Fibrosis, 471.3ms
# Speed: 5.9ms preprocess, 471.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001362_012.png
#  → Atelectasis: 0.54 - Caixa: [520, 397, 768, 585]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_013.png: 640x640 1 Fibrosis, 463.8ms
# Speed: 6.8ms preprocess, 463.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001362_013.png
#  → Fibrosis: 0.63 - Caixa: [746, 411, 837, 456]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_014.png: 640x640 (no detections), 446.8ms
# Speed: 5.7ms preprocess, 446.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_015.png: 640x640 1 Effusion, 452.5ms
# Speed: 6.9ms preprocess, 452.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001362_015.png
#  → Effusion: 0.69 - Caixa: [606, 590, 879, 754]
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_016.png: 640x640 (no detections), 451.0ms
# Speed: 5.7ms preprocess, 451.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\Faculdade\Mestrado\2 Semestre\APVC\ProjectV2\..\Project\data_set\images_002\images\00001362_017.png: 640x640 1 Consolidation, 1 Effusion, 446.3ms
# Speed: 7.0ms preprocess, 446.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 00001362_017.png
#  → Effusion: 0.65 - Caixa: [106, 298, 406, 904]
#  → Consolidation: 0.54 - Caixa: [566, 541, 733, 683]

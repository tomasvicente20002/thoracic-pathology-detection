# %% [markdown]
# # 🔍 YOLOv8 - Deteção com Filtragem Manual por IOU (NMS)
# Este notebook executa deteção de objetos usando um modelo YOLOv8 treinado, aplicando Non-Maximum Suppression (NMS) manual para eliminar caixas sobrepostas com base no limiar de IOU.

# %%
# Instalação necessária (caso ainda não esteja instalada)
# !pip install ultralytics opencv-python
# Out:
# Requirement already satisfied: ultralytics in c:\users\lynxv\anaconda3\lib\site-packages (8.3.162)
# Requirement already satisfied: opencv-python in c:\users\lynxv\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (2.7.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (0.22.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\lynxv\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\lynxv\anaconda3\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lynxv\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lynxv\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lynxv\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lynxv\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lynxv\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lynxv\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lynxv\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\lynxv\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (75.1.0)
# Requirement already satisfied: colorama in c:\users\lynxv\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\lynxv\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lynxv\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lynxv\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)

# %%
from ultralytics import YOLO
import cv2
import os
import torch
import torchvision.ops as ops

# %% [markdown]
# ## ⚙️ Configurações do modelo e parâmetros

# %%
# Caminho relativo (a partir do local onde está o notebook)
MODELO = 'model/y8s_finetune15/weights/best.pt'

PASTA_IMAGENS = 'chestx_det10_yolo/images/val'

# Thresholds
THRESHOLD = 0.3
IOU_THRESHOLD = 0.4  # Threshold para Non-Maximum Suppression

# %% [markdown]
# ## 🧮 Fórmula da Interseção sobre União (IOU)
# **IOU** mede a sobreposição entre duas bounding boxes. A fórmula é:
#
# $$ IOU = \frac{Área\ da\ Interseção}{Área\ da\ União} $$
#
# Usa-se para decidir se duas caixas estão demasiado próximas e apenas a de maior confiança deve ser mantida.

# %%
# Carregar o modelo YOLO treinado
model = YOLO(MODELO)

# %%
def filtrar_por_iou(boxes, scores, labels, iou_thresh=0.4):
    if len(boxes) == 0:
        return [], [], []
    keep_idxs = ops.nms(torch.tensor(boxes, dtype=torch.float32),
                       torch.tensor(scores, dtype=torch.float32),
                       iou_thresh)
    boxes_filtradas = [boxes[i] for i in keep_idxs]
    scores_filtrados = [scores[i] for i in keep_idxs]
    labels_filtradas = [labels[i] for i in keep_idxs]
    return boxes_filtradas, scores_filtrados, labels_filtradas

# %%
for nome_ficheiro in os.listdir(PASTA_IMAGENS):
    if nome_ficheiro.lower().endswith(('.jpg', '.jpeg', '.png')):
        caminho_imagem = os.path.join(PASTA_IMAGENS, nome_ficheiro)
        results = model(caminho_imagem)
        img = cv2.imread(caminho_imagem)

        boxes, scores, labels = [], [], []

        for box in results[0].boxes:
            conf = float(box.conf[0])
            if conf >= THRESHOLD:
                cls = int(box.cls[0])
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                boxes.append([x1, y1, x2, y2])
                scores.append(conf)
                labels.append(model.names[cls])

        if boxes:
            print(f"⚠️ Deteções na imagem: {nome_ficheiro}")
            boxes_filtradas, scores_filtrados, labels_filtradas = filtrar_por_iou(
                boxes, scores, labels, iou_thresh=IOU_THRESHOLD)

            for box, conf, nome in zip(boxes_filtradas, scores_filtrados, labels_filtradas):
                x1, y1, x2, y2 = box
                label = f"{nome} {conf:.2f}"
                cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
                (text_width, text_height), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 1)
                cv2.rectangle(img, (x1, y1 - text_height - 6), (x1 + text_width, y1), (0, 255, 0), -1)
                cv2.putText(img, label, (x1, y1 - 4), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 1)
                print(f" → {nome}: {conf:.2f} - Caixa: {[x1, y1, x2, y2]}")

            cv2.imshow("Deteções", img)
            cv2.waitKey(0)
            cv2.destroyAllWindows()

print("✅ Processo concluído.")
# Out:
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36200.png: 640x640 1 Fibrosis, 1 Nodule, 220.0ms
# Speed: 8.5ms preprocess, 220.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36201.png: 640x640 (no detections), 236.4ms
# Speed: 7.8ms preprocess, 236.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36202.png: 640x640 (no detections), 218.5ms
# Speed: 7.8ms preprocess, 218.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36203.png: 640x640 (no detections), 216.6ms
# Speed: 6.7ms preprocess, 216.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36204.png: 640x640 1 Nodule, 218.0ms
# Speed: 7.4ms preprocess, 218.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36204.png
#  → Nodule: 0.65 - Caixa: [231, 667, 256, 693]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36205.png: 640x640 28 Nodules, 244.3ms
# Speed: 8.5ms preprocess, 244.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36205.png
#  → Nodule: 0.87 - Caixa: [156, 101, 216, 159]
#  → Nodule: 0.86 - Caixa: [883, 216, 960, 297]
#  → Nodule: 0.85 - Caixa: [861, 688, 929, 793]
#  → Nodule: 0.85 - Caixa: [101, 454, 167, 525]
#  → Nodule: 0.84 - Caixa: [176, 640, 250, 721]
#  → Nodule: 0.84 - Caixa: [413, 204, 496, 263]
#  → Nodule: 0.83 - Caixa: [926, 492, 1000, 599]
#  → Nodule: 0.79 - Caixa: [819, 500, 876, 566]
#  → Nodule: 0.75 - Caixa: [126, 706, 169, 757]
#  → Nodule: 0.73 - Caixa: [63, 756, 106, 818]
#  → Nodule: 0.72 - Caixa: [338, 232, 405, 304]
#  → Nodule: 0.72 - Caixa: [885, 813, 941, 908]
#  → Nodule: 0.68 - Caixa: [607, 207, 658, 262]
#  → Nodule: 0.62 - Caixa: [112, 603, 152, 716]
#  → Nodule: 0.61 - Caixa: [893, 493, 944, 605]
#  → Nodule: 0.57 - Caixa: [69, 898, 110, 956]
#  → Nodule: 0.56 - Caixa: [205, 519, 249, 570]
#  → Nodule: 0.55 - Caixa: [95, 794, 143, 859]
#  → Nodule: 0.52 - Caixa: [161, 387, 202, 461]
#  → Nodule: 0.37 - Caixa: [625, 57, 670, 101]
#  → Nodule: 0.34 - Caixa: [929, 691, 967, 828]
#  → Nodule: 0.32 - Caixa: [906, 831, 975, 997]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36206.png: 640x640 1 Consolidation, 2 Nodules, 388.4ms
# Speed: 9.0ms preprocess, 388.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36206.png
#  → Consolidation: 0.88 - Caixa: [662, 591, 856, 804]
#  → Nodule: 0.85 - Caixa: [769, 508, 814, 565]
#  → Nodule: 0.74 - Caixa: [208, 593, 247, 649]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36209.png: 640x640 3 Effusions, 2 Fractures, 260.5ms
# Speed: 9.1ms preprocess, 260.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36209.png
#  → Effusion: 0.91 - Caixa: [49, 514, 204, 654]
#  → Effusion: 0.88 - Caixa: [12, 598, 358, 805]
#  → Effusion: 0.80 - Caixa: [839, 673, 880, 745]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36210.png: 640x640 1 Nodule, 243.9ms
# Speed: 7.8ms preprocess, 243.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36210.png
#  → Nodule: 0.82 - Caixa: [237, 302, 282, 355]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36216.png: 640x640 1 Consolidation, 1 Effusion, 243.5ms
# Speed: 8.1ms preprocess, 243.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36216.png
#  → Consolidation: 0.90 - Caixa: [222, 511, 446, 789]
#  → Effusion: 0.73 - Caixa: [125, 737, 438, 905]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36217.png: 640x640 (no detections), 244.5ms
# Speed: 8.7ms preprocess, 244.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36218.png: 640x640 2 Fibrosiss, 209.9ms
# Speed: 6.5ms preprocess, 209.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36218.png
#  → Fibrosis: 0.79 - Caixa: [609, 141, 672, 263]
#  → Fibrosis: 0.76 - Caixa: [415, 139, 492, 260]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36221.png: 640x640 (no detections), 296.0ms
# Speed: 11.2ms preprocess, 296.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36223.png: 640x640 (no detections), 210.6ms
# Speed: 6.8ms preprocess, 210.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36224.png: 640x640 2 Consolidations, 2 Emphysemas, 207.6ms
# Speed: 7.5ms preprocess, 207.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36224.png
#  → Consolidation: 0.84 - Caixa: [566, 64, 877, 981]
#  → Emphysema: 0.84 - Caixa: [125, 55, 457, 963]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36226.png: 640x640 (no detections), 245.7ms
# Speed: 9.0ms preprocess, 245.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36229.png: 640x640 (no detections), 209.9ms
# Speed: 7.0ms preprocess, 209.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36231.png: 640x640 (no detections), 207.9ms
# Speed: 5.6ms preprocess, 207.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36233.png: 640x640 (no detections), 205.0ms
# Speed: 5.4ms preprocess, 205.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36234.png: 640x640 3 Atelectasiss, 211.8ms
# Speed: 7.6ms preprocess, 211.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36234.png
#  → Atelectasis: 0.89 - Caixa: [705, 695, 933, 760]
#  → Atelectasis: 0.74 - Caixa: [159, 741, 476, 794]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36236.png: 640x640 2 Atelectasiss, 245.0ms
# Speed: 9.7ms preprocess, 245.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36236.png
#  → Atelectasis: 0.75 - Caixa: [752, 702, 918, 802]
#  → Atelectasis: 0.45 - Caixa: [152, 811, 491, 865]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36237.png: 640x640 2 Fractures, 237.0ms
# Speed: 7.9ms preprocess, 237.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36237.png
#  → Fracture: 0.88 - Caixa: [794, 337, 868, 422]
#  → Fracture: 0.78 - Caixa: [807, 410, 863, 491]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36239.png: 640x640 1 Effusion, 272.5ms
# Speed: 8.8ms preprocess, 272.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36239.png
#  → Effusion: 0.89 - Caixa: [710, 714, 904, 851]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36240.png: 640x640 1 Effusion, 259.3ms
# Speed: 11.1ms preprocess, 259.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36240.png
#  → Effusion: 0.71 - Caixa: [107, 748, 145, 818]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36241.png: 640x640 1 Atelectasis, 251.6ms
# Speed: 9.9ms preprocess, 251.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36241.png
#  → Atelectasis: 0.87 - Caixa: [197, 557, 459, 901]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36243.png: 640x640 (no detections), 252.0ms
# Speed: 8.6ms preprocess, 252.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36244.png: 640x640 1 Atelectasis, 1 Consolidation, 1 Pneumothorax, 209.6ms
# Speed: 6.8ms preprocess, 209.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36244.png
#  → Pneumothorax: 0.83 - Caixa: [281, 118, 454, 186]
#  → Consolidation: 0.40 - Caixa: [325, 517, 475, 755]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36247.png: 640x640 1 Effusion, 300.1ms
# Speed: 10.5ms preprocess, 300.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36247.png
#  → Effusion: 0.91 - Caixa: [116, 743, 429, 1022]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36248.png: 640x640 2 Fibrosiss, 256.9ms
# Speed: 8.5ms preprocess, 256.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36248.png
#  → Fibrosis: 0.89 - Caixa: [635, 726, 908, 979]
#  → Fibrosis: 0.86 - Caixa: [143, 607, 459, 902]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36251.png: 640x640 1 Atelectasis, 272.0ms
# Speed: 8.0ms preprocess, 272.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36251.png
#  → Atelectasis: 0.86 - Caixa: [768, 789, 954, 858]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36253.png: 640x640 2 Atelectasiss, 258.3ms
# Speed: 11.1ms preprocess, 258.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36253.png
#  → Atelectasis: 0.90 - Caixa: [636, 533, 826, 612]
#  → Atelectasis: 0.88 - Caixa: [122, 489, 370, 599]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36254.png: 640x640 1 Atelectasis, 1 Consolidation, 2 Effusions, 237.4ms
# Speed: 8.7ms preprocess, 237.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36254.png
#  → Effusion: 0.85 - Caixa: [589, 534, 910, 695]
#  → Atelectasis: 0.80 - Caixa: [113, 497, 376, 584]
#  → Consolidation: 0.77 - Caixa: [722, 469, 878, 532]
#  → Effusion: 0.59 - Caixa: [91, 584, 428, 694]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36255.png: 640x640 1 Nodule, 333.7ms
# Speed: 41.8ms preprocess, 333.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36255.png
#  → Nodule: 0.87 - Caixa: [305, 460, 400, 540]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36256.png: 640x640 (no detections), 264.5ms
# Speed: 8.9ms preprocess, 264.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36257.png: 640x640 1 Atelectasis, 208.1ms
# Speed: 7.4ms preprocess, 208.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36257.png
#  → Atelectasis: 0.91 - Caixa: [634, 672, 862, 755]
#
# image 1/1 c:\Users\lynxv\Desktop\GitHub\projecto-apvc\project-apvc\chestx_det10_yolo\images\train\36259.png: 640x640 1 Effusion, 233.1ms
# Speed: 7.9ms preprocess, 233.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# ⚠️ Deteções na imagem: 36259.png
#  → Effusion: 0.87 - Caixa: [753, 874, 829, 983]
